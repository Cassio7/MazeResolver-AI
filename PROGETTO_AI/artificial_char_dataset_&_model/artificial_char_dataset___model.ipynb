# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pillow

# %%
from PIL import Image
from PIL import ImageDraw, ImageFont, ImageFilter
import random
import os
import numpy as np
import string

from matplotlib import pyplot as plt

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.utils import to_categorical

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # DATASET GENERATOR

# %%
dir = "/content/drive/MyDrive/Colab Notebooks/PROGETTO_AI/artificial_char_dataset_&_model/"

font_paths = [
    "fonts/Montserrat-Regular.ttf",
    "fonts/AbrilFatface-Regular.ttf",
    "fonts/CormorantGaramond-Bold.ttf",
    "fonts/CormorantGaramond-BoldItalic.ttf",
    "fonts/CormorantGaramond-Italic.ttf",
    "fonts/CormorantGaramond-Light.ttf",
    "fonts/CormorantGaramond-Medium.ttf",
    "fonts/CormorantGaramond-MediumItalic.ttf",
    "fonts/CormorantGaramond-Regular.ttf",
    "fonts/CormorantGaramond-SemiBold.ttf",
    "fonts/CormorantGaramond-SemiBoldItalic.ttf",
    "fonts/CrimsonText-Bold.ttf",
    "fonts/CrimsonText-BoldItalic.ttf",
    "fonts/CrimsonText-Italic.ttf",
    "fonts/CrimsonText-Regular.ttf",
    "fonts/CrimsonText-SemiBold.ttf",
    "fonts/DMSerifDisplay-Italic.ttf",
    "fonts/DMSerifDisplay-Regular.ttf",
    "fonts/EBGaramond-Bold.ttf",
    "fonts/EBGaramond-BoldItalic.ttf",
    "fonts/EBGaramond-ExtraBold.ttf",
    "fonts/EBGaramond-ExtraBoldItalic.ttf",
    "fonts/EBGaramond-Italic.ttf",
    "fonts/EBGaramond-Medium.ttf",
    "fonts/EBGaramond-MediumItalic.ttf",
    "fonts/EBGaramond-Regular.ttf",
    "fonts/EBGaramond-SemiBold.ttf",
    "fonts/EBGaramond-SemiBoldItalic.ttf",
    "fonts/EBGaramond-Regular.ttf",
    "fonts/FjallaOne-Regular.ttf",
    "fonts/Inconsolata-Black.ttf",
    "fonts/Inconsolata-Bold.ttf",
    "fonts/Inconsolata-ExtraBold.ttf",
    "fonts/Inconsolata-ExtraLight.ttf",
    "fonts/Inconsolata-Light.ttf",
    "fonts/Inconsolata-Medium.ttf",
    "fonts/Inconsolata-Regular.ttf",
    "fonts/Inconsolata-SemiBold.ttf",
    "fonts/JosefinSans-Bold.ttf",
    "fonts/JosefinSans-BoldItalic.ttf",
    "fonts/JosefinSans-ExtraLight.ttf",
    "fonts/JosefinSans-ExtraLightItalic.ttf",
    "fonts/JosefinSans-Italic.ttf",
    "fonts/JosefinSans-Light.ttf",
    "fonts/JosefinSans-LightItalic.ttf",
    "fonts/JosefinSans-Medium.ttf",
    "fonts/JosefinSans-MediumItalic.ttf",
    "fonts/JosefinSans-Regular.ttf",
    "fonts/JosefinSans-SemiBold.ttf",
    "fonts/JosefinSans-SemiBoldItalic.ttf",
    "fonts/JosefinSans-Thin.ttf",
    "fonts/JosefinSans-ThinItalic.ttf",
    "fonts/OpenSans-Bold.ttf",
    "fonts/OpenSans-BoldItalic.ttf",
    "fonts/OpenSans-ExtraBold.ttf",
    "fonts/OpenSans-ExtraBoldItalic.ttf",
    "fonts/OpenSans-Italic.ttf",
    "fonts/OpenSans-Light.ttf",
    "fonts/OpenSans-LightItalic.ttf",
    "fonts/OpenSans-Medium.ttf",
    "fonts/OpenSans-MediumItalic.ttf",
    "fonts/OpenSans-Regular.ttf",
    "fonts/OpenSans-SemiBold.ttf",
    "fonts/OpenSans-SemiBoldItalic.ttf",
    "fonts/Phudu-Black.ttf",
    "fonts/Phudu-Bold.ttf",
    "fonts/Phudu-ExtraBold.ttf",
    "fonts/Phudu-Light.ttf",
    "fonts/Phudu-Medium.ttf",
    "fonts/Phudu-Regular.ttf",
    "fonts/Phudu-SemiBold.ttf",
    "fonts/PlayfairDisplay-Black.ttf",
    "fonts/PlayfairDisplay-Bold.ttf",
    "fonts/PlayfairDisplay-ExtraBold.ttf",
    "fonts/PlayfairDisplay-Italic.ttf",
    "fonts/PlayfairDisplay-Medium.ttf",
    "fonts/PlayfairDisplay-ExtraBoldItalic.ttf",
    "fonts/PlayfairDisplay-MediumItalic.ttf",
    "fonts/PlayfairDisplay-Regular.ttf",
    "fonts/PlayfairDisplay-SemiBold.ttf",
    "fonts/PlayfairDisplay-SemiBoldItalic.ttf",
    "fonts/Raleway-Black.ttf",
    "fonts/Raleway-Bold.ttf",
    "fonts/Raleway-BoldItalic.ttf",
    "fonts/Raleway-Italic.ttf",
    "fonts/Raleway-Light.ttf",
    "fonts/Raleway-Medium.ttf",
    "fonts/Raleway-Regular.ttf",
    "fonts/Raleway-SemiBold.ttf",
    "fonts/Raleway-Thin.ttf",
    "fonts/RobotoCondensed-Bold.ttf",
    "fonts/RobotoCondensed-BoldItalic.ttf",
    "fonts/RobotoCondensed-Italic.ttf",
    "fonts/RobotoCondensed-Light.ttf",
    "fonts/RobotoCondensed-LightItalic.ttf",
    "fonts/RobotoCondensed-Regular.ttf",
    "fonts/RobotoSlab-Black.ttf",
    "fonts/RobotoSlab-Bold.ttf",
    "fonts/RobotoSlab-ExtraBold.ttf",
    "fonts/RobotoSlab-ExtraLight.ttf",
    "fonts/RobotoSlab-Light.ttf",
    "fonts/RobotoSlab-Medium.ttf",
    "fonts/RobotoSlab-Regular.ttf",
    "fonts/RobotoSlab-SemiBold.ttf",
    "fonts/RobotoSlab-Thin.ttf",
    "fonts/ShadowsIntoLight-Regular.ttf",
    "fonts/ChakraPetch-Bold.ttf",
    "fonts/ChakraPetch-Light.ttf",
    "fonts/ChakraPetch-Medium.ttf",
    "fonts/ChakraPetch-Regular.ttf",
    "fonts/ChakraPetch-Bold.ttf",
    "fonts/ChakraPetch-Light.ttf",
    "fonts/ChakraPetch-Medium.ttf",
    "fonts/ChakraPetch-Regular.ttf",
    "fonts/AdventPro_Expanded-Bold.ttf",
    "fonts/AdventPro_Expanded-ExtraLight.ttf",
    "fonts/AdventPro_Expanded-Light.ttf",
    "fonts/AdventPro_Expanded-Thin.ttf",
    "fonts/AdventPro_Expanded-Regular.ttf",
    "fonts/AdventPro_Expanded-Medium.ttf",
    "fonts/Antonio-Bold.ttf",
    "fonts/Antonio-Light.ttf",
    "fonts/Antonio-Regular.ttf",
    "fonts/Antonio-Thin.ttf",
    "fonts/CabinSketch-Regular.ttf",
    "fonts/CabinSketch-Bold.ttf",
    "fonts/Changa-Bold.ttf",
    "fonts/Changa-Regular.ttf",
    "fonts/Changa-Light.ttf",
    "fonts/Changa-ExtraLight.ttf",
    "fonts/CinzelDecorative-Black.ttf",
    "fonts/CinzelDecorative-Regular.ttf",
    "fonts/CinzelDecorative-Bold.ttf",
    "fonts/Comfortaa-Regular.ttf",
    "fonts/Comfortaa-Light.ttf",
    "fonts/Comfortaa-Bold.ttf",
    "fonts/Dosis-Regular.ttf",
    "fonts/Dosis-Light.ttf",
    "fonts/Dosis-ExtraLight.ttf",
    "fonts/Dosis-Bold.ttf",
    "fonts/Handjet-Thin.ttf",
    "fonts/Handjet-Regular.ttf",
    "fonts/Handjet-Light.ttf",
    "fonts/Handjet-Bold.ttf",
    "fonts/Imbue_24pt-Regular.ttf",
    "fonts/Imbue_24pt-Light.ttf",
    "fonts/Imbue_24pt-Bold.ttf",
    "fonts/InterTight-Thin.ttf",
    "fonts/InterTight-Regular.ttf",
    "fonts/InterTight-Light.ttf",
    "fonts/InterTight-Bold.ttf",
    "fonts/JosefinSans-Bold.ttf",
    "fonts/IstokWeb-Regular.ttf",
    "fonts/IstokWeb-Italic.ttf",
    "fonts/Orbitron-Regular.ttf",
    "fonts/Orbitron-Medium.ttf",
    "fonts/Orbitron-Bold.ttf",
    "fonts/PassionOne-Regular.ttf",
    "fonts/PassionOne-Bold.ttf",
    "fonts/Play-Regular.ttf",
    "fonts/Play-Bold.ttf",
    "fonts/Quantico-Regular.ttf",
    "fonts/Quantico-Italic.ttf",
    "fonts/Quantico-Bold.ttf",
    "fonts/RedHatDisplay-Regular.ttf",
    "fonts/RedHatDisplay-Medium.ttf",
    "fonts/RedHatDisplay-Light.ttf",
    "fonts/RedHatDisplay-Italic.ttf",
    "fonts/RedHatDisplay-Bold.ttf",
    "fonts/Rowdies-Regular.ttf",
    "fonts/Rowdies-Light.ttf",
    "fonts/Rowdies-Bold.ttf",
    "fonts/Saira_Condensed-Regular.ttf",
    "fonts/Saira_Condensed-Light.ttf",
    "fonts/Saira_Condensed-Bold.ttf",
    "fonts/Sarabun-Medium.ttf",
    "fonts/Sarabun-Light.ttf",
    "fonts/Sarabun-Bold.ttf",
    "fonts/Sarala-Regular.ttf",
    "fonts/Sarala-Bold.ttf",
    "fonts/Syncopate-Regular.ttf",
    "fonts/Syncopate-Bold.ttf",
    "fonts/Syne-Regular.ttf",
    "fonts/Syne-Medium.ttf",
    "fonts/Syne-Bold.ttf",
    "fonts/Teko-Medium.ttf",
    "fonts/Teko-Light.ttf",
    "fonts/Teko-Bold.ttf",
    "fonts/Tektur-Regular.ttf",
    "fonts/Tektur-Bold.ttf",
    "fonts/Tillana-Regular.ttf",
    "fonts/Tillana-Bold.ttf",
    "fonts/TitilliumWeb-Regular.ttf",
    "fonts/TitilliumWeb-Light.ttf",
    "fonts/TitilliumWeb-ExtraLight.ttf",
    "fonts/TitilliumWeb-Bold.ttf",
    "fonts/Urbanist-Light.ttf",
    "fonts/Urbanist-Bold.ttf",
    "fonts/Urbanist-Regular.ttf",
    "fonts/YanoneKaffeesatz-Medium.ttf",
    "fonts/YanoneKaffeesatz-Light.ttf",
    "fonts/YanoneKaffeesatz-ExtraLight.ttf",
    "fonts/YanoneKaffeesatz-Bold.ttf",
    "fonts/Yantramanav-Thin.ttf",
    "fonts/Yantramanav-Regular.ttf",
    "fonts/Yantramanav-Medium.ttf",
    "fonts/Yantramanav-Light.ttf",
    "fonts/Yantramanav-Bold.ttf",
]

# questo for va fatto solo se si vogliono prendere i fonts dal drive
for i in range(len(font_paths)):
  font_paths[i] = dir + font_paths[i]
  #print(font_paths[i])
  # if os.path.exists(font_paths[i]):
  #    print("font TROVATO")
  # else:
  #   print("font NON TROVATO")


font_size = 15

# %%
dir = "/content/drive/MyDrive/Colab Notebooks/PROGETTO_AI/artificial_char_dataset_&_model/"

font_paths = [
    "fonts/ShadowsIntoLight-Regular.ttf",
    "fonts/ChakraPetch-Bold.ttf",
    "fonts/ChakraPetch-Light.ttf",
    "fonts/ChakraPetch-Medium.ttf",
    "fonts/ChakraPetch-Regular.ttf",
    "fonts/ChakraPetch-Bold.ttf",
    "fonts/ChakraPetch-Light.ttf",
    "fonts/ChakraPetch-Medium.ttf",
    "fonts/ChakraPetch-Regular.ttf",
    "fonts/AdventPro_Expanded-Bold.ttf",
    "fonts/AdventPro_Expanded-ExtraLight.ttf",
    "fonts/AdventPro_Expanded-Light.ttf",
    "fonts/AdventPro_Expanded-Thin.ttf",
    "fonts/AdventPro_Expanded-Regular.ttf",
    "fonts/AdventPro_Expanded-Medium.ttf",
    "fonts/Antonio-Bold.ttf",
    "fonts/Antonio-Light.ttf",
    "fonts/Antonio-Regular.ttf",
    "fonts/Antonio-Thin.ttf",
    "fonts/CabinSketch-Regular.ttf",
    "fonts/CabinSketch-Bold.ttf",
    "fonts/Changa-Bold.ttf",
    "fonts/Changa-Regular.ttf",
    "fonts/Changa-Light.ttf",
    "fonts/Changa-ExtraLight.ttf",
    "fonts/CinzelDecorative-Black.ttf",
    "fonts/CinzelDecorative-Regular.ttf",
    "fonts/CinzelDecorative-Bold.ttf",
    "fonts/Comfortaa-Regular.ttf",
    "fonts/Comfortaa-Light.ttf",
    "fonts/Comfortaa-Bold.ttf",
    "fonts/Dosis-Regular.ttf",
    "fonts/Dosis-Light.ttf",
    "fonts/Dosis-ExtraLight.ttf",
    "fonts/Dosis-Bold.ttf",
    "fonts/Handjet-Thin.ttf",
    "fonts/Handjet-Regular.ttf",
    "fonts/Handjet-Light.ttf",
    "fonts/Handjet-Bold.ttf",
    "fonts/Imbue_24pt-Regular.ttf",
    "fonts/Imbue_24pt-Light.ttf",
    "fonts/Imbue_24pt-Bold.ttf",
    "fonts/InterTight-Thin.ttf",
    "fonts/InterTight-Regular.ttf",
    "fonts/InterTight-Light.ttf",
    "fonts/InterTight-Bold.ttf",
    "fonts/JosefinSans-Bold.ttf",
    "fonts/IstokWeb-Regular.ttf",
    "fonts/IstokWeb-Italic.ttf",
    "fonts/Orbitron-Regular.ttf",
    "fonts/Orbitron-Medium.ttf",
    "fonts/Orbitron-Bold.ttf",
    "fonts/PassionOne-Regular.ttf",
    "fonts/PassionOne-Bold.ttf",
    "fonts/Play-Regular.ttf",
    "fonts/Play-Bold.ttf",
    "fonts/Quantico-Regular.ttf",
    "fonts/Quantico-Italic.ttf",
    "fonts/Quantico-Bold.ttf",
    "fonts/RedHatDisplay-Regular.ttf",
    "fonts/RedHatDisplay-Medium.ttf",
    "fonts/RedHatDisplay-Light.ttf",
    "fonts/RedHatDisplay-Italic.ttf",
    "fonts/RedHatDisplay-Bold.ttf",
    "fonts/Rowdies-Regular.ttf",
    "fonts/Rowdies-Light.ttf",
    "fonts/Rowdies-Bold.ttf",
    "fonts/Saira_Condensed-Regular.ttf",
    "fonts/Saira_Condensed-Light.ttf",
    "fonts/Saira_Condensed-Bold.ttf",
    "fonts/Sarabun-Medium.ttf",
    "fonts/Sarabun-Light.ttf",
    "fonts/Sarabun-Bold.ttf",
    "fonts/Sarala-Regular.ttf",
    "fonts/Sarala-Bold.ttf",
    "fonts/Syncopate-Regular.ttf",
    "fonts/Syncopate-Bold.ttf",
    "fonts/Syne-Regular.ttf",
    "fonts/Syne-Medium.ttf",
    "fonts/Syne-Bold.ttf",
    "fonts/Teko-Medium.ttf",
    "fonts/Teko-Light.ttf",
    "fonts/Teko-Bold.ttf",
    "fonts/Tektur-Regular.ttf",
    "fonts/Tektur-Bold.ttf",
    "fonts/Tillana-Regular.ttf",
    "fonts/Tillana-Bold.ttf",
    "fonts/TitilliumWeb-Regular.ttf",
    "fonts/TitilliumWeb-Light.ttf",
    "fonts/TitilliumWeb-ExtraLight.ttf",
    "fonts/TitilliumWeb-Bold.ttf",
    "fonts/Urbanist-Light.ttf",
    "fonts/Urbanist-Bold.ttf",
    "fonts/Urbanist-Regular.ttf",
    "fonts/YanoneKaffeesatz-Medium.ttf",
    "fonts/YanoneKaffeesatz-Light.ttf",
    "fonts/YanoneKaffeesatz-ExtraLight.ttf",
    "fonts/YanoneKaffeesatz-Bold.ttf",
    "fonts/Yantramanav-Thin.ttf",
    "fonts/Yantramanav-Regular.ttf",
    "fonts/Yantramanav-Medium.ttf",
    "fonts/Yantramanav-Light.ttf",
    "fonts/Yantramanav-Bold.ttf",
    "fonts/AmaticSC-Regular.ttf",
    "fonts/AmaticSC-Bold.ttf",
]

# questo for va fatto solo se si vogliono prendere i fonts dal drive
for i in range(len(font_paths)):
  font_paths[i] = dir + font_paths[i]
  print(font_paths[i])
  if os.path.exists(font_paths[i]):
     print("font TROVATO")
  else:
    print("font NON TROVATO")


font_size = 15

# %%
#GENERATORE CON CARTELLE SUDDIVISE

width, height = 28, 28
#background_color = (255, 255, 255)  # bianco
background_color = (0, 0, 0)  # nero
#text_color = (0, 0, 0)  # testo di colore nero
text_color = (255, 255, 255)  #  bianco

output_directory = "dataset"
#output_directory = "/content/drive/MyDrive/Colab Notebooks/PROGETTO_AI/artificial_char_dataset_&_model/dataset"

#letters = ['S', 'E', 'X', '0', '1', '2', '3', '4']
letters = ['S', 'E', 'X', '1', '2', '3', '4'] # LO 0 DEVE ESSERE TOLTO

if not os.path.exists(output_directory):
    os.makedirs(output_directory)

for letter in letters:
    class_directory = os.path.join(output_directory, letter)

    # Crea la cartella della classe se non esiste
    if not os.path.exists(class_directory):
        os.makedirs(class_directory)

    for i in range(12000):
        img = Image.new('RGB', (width, height), background_color)
        draw = ImageDraw.Draw(img)

        label = letter

        # font casuale fra quelli scelti
        random_font_path = random.choice(font_paths)
        font = ImageFont.truetype(random_font_path, font_size)

        # per centrare il carattere nell'immagine
        # = character_draw.text
        # text_width, text_height = character_draw.textsize(label, font=font)
        # x = (width - text_width) // 2
        # y = (height - text_height) // 2
        text_bbox = character_draw.textbbox((0, 0), label, font=font)
        text_width = text_bbox[2] - text_bbox[0]
        text_height = text_bbox[3] - text_bbox[1]

        x = (width - text_width) // 2
        y = (height - text_height) // 2

        # applico rotazioni all'immagine per dargli distorsione
        rotated_img = Image.new('RGB', (width, height), background_color) # crea una nuova immagine
        rotated_draw = ImageDraw.Draw(rotated_img) #oggetto associato all'immagine per disegnarci sopra
        rotated_img.paste(img, (0, 0))
        rotated_character_img = Image.new('RGBA', (width, height), (0, 0, 0, 0))
        character_draw = ImageDraw.Draw(rotated_character_img)
        character_draw.text((x, y-3), label, font=font, fill=text_color) # fill = (255,255,255,255)
        rotated_character_img = rotated_character_img.rotate(random.randint(-5, 5), resample=Image.BICUBIC)

        # Applico un grado casuale di sbiadita da 0 a 5
        radius = random.randint(0, 5)
        rotated_img = rotated_img.filter(ImageFilter.GaussianBlur(radius=1000))

        rotated_img.paste(rotated_character_img, (0, 0), mask=rotated_character_img)

        #image_filename = os.path.join(class_directory, f"{letter}_{i}.png")
        image_filename = os.path.join(class_directory, f"{letter}_{i}.jpeg")
        rotated_img.save(image_filename)

        if i % 1000 == 0:
          print(f"1000 ELEMENTI DELLA LETTERA: {letter}")

        # SALVA IL DATASET IN UN DIZIONARIO
        # image = Image.open(image_filename)
        # image_array = np.array(image)
        # #image_array = np.array(image_filename)
        # label_array = np.array(label)

        # dataset[i] = []
        # dataset[i].append({'image': image_array, 'label': label_array})

        # print(f'Immagine {i+1}:')
        # print(image_array)  # Stampa l'array dell'immagine
        # print(f'Label {i+1}: {label_array}')  # Stampa la label corrispondente
        # print('---------------------------------')

# %% [markdown]
# # MODEL GENERATOR

# %%
# FUNZIONE PER L'ESTRAZIONE DEL DATASET CON IMMAGINI DI CARATTERI ARTIFICIALI
def extract_my_dataset(dataset_directory):
    images = []
    labels = []

    # Elabora ogni classe all'interno della cartella del dataset
    for class_label in os.listdir(dataset_directory):
        class_directory = os.path.join(dataset_directory, class_label)

        # Ignora i file non directory
        if not os.path.isdir(class_directory):
            continue

        # Estrai le immagini dalla classe corrente
        for image_filename in os.listdir(class_directory):
            if image_filename.endswith(".png"):
                image_path = os.path.join(class_directory, image_filename)

                # Carica l'immagine e convertila in scala di grigi
                image = Image.open(image_path).convert('L') # convert('L') per la scala di grigi
                image_array = np.array(image)

                # Estrai la label dalla nome del file (supponendo che il nome del file sia nel formato "lettera_numero.png")
                label = image_filename.split("_")[0]

                images.append(image_array)
                labels.append(label)

    return np.array(images), np.array(labels)

# %%
# ESTRAZIONE DEL DATASET IN MODO PARALLELO

import multiprocessing

def extract_images_from_class(class_directory):
    images = []
    labels = []

    for image_filename in os.listdir(class_directory):
        if image_filename.endswith(".png") or image_filename.endswith(".jpeg"):
            image_path = os.path.join(class_directory, image_filename)
            image = Image.open(image_path).convert('L')
            image_array = np.array(image)
            label = image_filename.split("_")[0]
            images.append(image_array)
            labels.append(label)

    return images, labels

def extract_my_dataset_parallel(dataset_directory):
    images = []
    labels = []

    for class_label in os.listdir(dataset_directory):
        class_directory = os.path.join(dataset_directory, class_label)

        if not os.path.isdir(class_directory):
            continue

        pool = multiprocessing.Pool()  # Creare un pool di processi
        results = pool.map(extract_images_from_class, [class_directory])
        pool.close()
        pool.join()

        for result in results:
            images.extend(result[0])
            labels.extend(result[1])

    return np.array(images), np.array(labels)

# %%
#import shutil

#dataset_dir = "/content/drive/MyDrive/Colab Notebooks/PROGETTO_AI/artificial_char_dataset_&_model/dataset//"
#destination_dir = "dataset"
#shutil.copytree(dataset_dir, destination_dir)

dataset_dir = "dataset"

art_images, art_labels = extract_my_dataset_parallel(dataset_dir)
print("Images shape:", art_images.shape)
print("Labels shape:", art_labels.shape)
print("Unique labels:", np.unique(art_labels).shape[0])
print("Number of unique labels:", len(np.unique(art_labels)))

# my_labels=[0, 1, 2, 3, 4, 'S', 'E', 'X']
# lookup = { '0': 0, '1':1, '2':2, '3':3, '4':4, 'E':5, 'S':6, 'X': 7}
#my_labels=[1, 2, 3, 4, 'S', 'E', 'X']
lookup = { '1':0, '2':1, '3':2, '4':3, 'E':4, 'S':5, 'X': 6}

i = 0
for label in art_labels:
  #print(label)
  art_labels[i] = lookup[str(label)] # aggiorno la label
  #print(label)
  i = i + 1
# Out:
# Images shape: (84000, 28, 28)
# Labels shape: (84000,)
# Unique labels: 7
# Number of unique labels: 7

# %%
# Normalize images to the range [0, 1]:
# calcola i valori minimi e massimi presenti nei dati, quindi normalizza i valori dei pixel in modo che siano nell'intervallo [0, 1].
# Alla fine dell'esecuzione di questo codice, images_normalized conterrà le immagini normalizzate, dove i valori dei pixel sono scalati nell'intervallo [0, 1].
feature_vector_length = 784
#scaler = MinMaxScaler()
#images_normalized = scaler.fit_transform(images.reshape(-1, feature_vector_length)) # le immagini vengono trasformate da una matrice 3D (28*28*1) a una 2D (784*1).
# Questo passaggio è necessario perchè MinMaxScaler lavora con matrici bidimensionali

images_normalized = art_images.astype("float32")/255
art_labels = art_labels.astype("float32")
#print(images_normalized[0])

#images_normalized = images_normalized.reshape(-1, 28, 28, 1) # le immagini vengono ripristinate alla forma di partenza 3D (28*28*1) - può anche non essere fatto

print("max pixel values : ",np.max(images_normalized))
print("min pixel values: ",np.min(images_normalized))

# Split dataset into training and testing sets
train_images, test_images, train_labels, test_labels = train_test_split(
    images_normalized, art_labels, test_size=0.1, random_state=100
) # test_size è la proporzioni di dati da allocare per il test_set (20%).
# random_state imposta il seed per il generatore di numeri casuali

print(train_images.shape)
print(train_labels.shape)

# %%
# Build the ANN model
# model = keras.Sequential([
#     Flatten(input_shape=(28, 28, 1)), # Flatten è utilizzato per "appiattire" i dati in modo che possano essere collegati a strati densi.
#     # flatten è necessario quando si lavora con dati multidimensionali, come immagini, che devono essere trasformati in un vettore unidimensionale
#     #Dropout( 0.3, input_shape = (feature_vector_length,)),
#     Dropout( 0.3),
#     Dense(128, activation='relu'),
#     Dense(64, activation='relu'),
#     Dense(len(np.unique(art_labels)), activation='softmax')
# ])
model = keras.Sequential([
    Flatten(input_shape=(28, 28, 1)),
    Dense(256, activation='relu'),  # Aumenta il numero di unità
    Dropout(0.5),  # Aggiungi dropout per prevenire l'overfitting
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(len(np.unique(art_labels)), activation='softmax')
])

model.summary()

# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
batch_size = 128 # 128
epochs = 7
model.fit(train_images, train_labels, batch_size=batch_size, epochs=epochs, validation_split=0.1)
# batch_size: durante ogni ciclo di addestramento verranno prese 128 immagini e le relative etichette alla volta per calcolare un aggiornamento dei pesi della rete.
# epochs = 1: indica che il modello verrà addestrato per un solo ciclo completo attraverso tutti i dati di addestramento.
# validation_split=0.1: indica che il 10% dei dati di addestramento verrà utilizzato come set di convalida per monitorare le prestazioni del modello durante l'addestramento.

# Evaluate the model on the test set
score = model.evaluate(test_images, test_labels, verbose=0)
print(f"Test loss: {score[0]}\nTest Accuracy: {score[1]}")

#model.save('/content/model/')
model.save("/content/drive/MyDrive/Colab Notebooks/PROGETTO_AI/artificial_char_dataset_&_model/model")

# %%
# Scegli un numero casuale di immagini da testare
num_images_to_test = 20

# Estrai casualmente un insieme di indici delle immagini dal set di test
random_image_indices = random.sample(range(len(test_images)), num_images_to_test)

# Loop attraverso le immagini selezionate casualmente
for i in random_image_indices:
    test_image = test_images[i]  # Estrai l'immagine di test
    true_label = int(test_labels[i])  # Estrai l'etichetta vera

    # Effettua la predizione con il modello
    prediction = model.predict(np.expand_dims(test_image, axis=0))
    predicted_class = prediction.argmax()  # Estrai l'etichetta predetta

    labels = {0: '1', 1:'2', 2:'3', 3:'4', 4:'E', 5: 'S', 6: 'X'} # i numeri non contano perchè sono già in ordine
    predicted_label = labels.get(predicted_class, str(predicted_class))

    print("La predizione è:", predicted_label)

    # Visualizza l'immagine di test
    plt.figure()
    plt.imshow(test_image.reshape(28, 28), cmap='gray')
    true_label = labels.get(true_label, str(true_label))
    plt.title(f"True Label: {true_label}, Predicted Label: {predicted_label}")
    plt.axis('off')
    plt.show()
